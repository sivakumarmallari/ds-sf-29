# %% [markdown]
# # Project 2
#
# In this project, you will implement the exploratory analysis plan developed in Project 1. This will lay the groundwork for our our first modeling exercise in Project 3.

# %% [markdown]
# ### Step 1: Load the python libraries you will need for this project

# %%
#imports
from __future__ import division
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import statsmodels.api as sm
import pylab as pl
import numpy as np
# %matplotlib inline

# %% [markdown]
# ### Step 2: Read in your data set

# %%
#Read in data from source 
df_raw = pd.read_csv("../assets/admissions.csv")
print df_raw.head()
# Out:
#    admit    gre   gpa  prestige
# 0      0  380.0  3.61       3.0
# 1      1  660.0  3.67       3.0
# 2      1  800.0  4.00       1.0
# 3      1  640.0  3.19       4.0
# 4      0  520.0  2.93       4.0

# %% [markdown]
# ## Questions
# #### Question 1. How many observations are in our dataset?

# %%
df_raw.count()
# Out:
# admit       400
# gre         398
# gpa         398
# prestige    399
# dtype: int64

# %% [markdown]
# Answer:
# admit       400
# gre         398
# gpa         398
# prestige    399

# %% [markdown]
# #### Question 2. Create a summary table

# %%
#function
#print df_raw.groupby('admit')['admit', 'gre', 'gpa'].head()
#print df_raw.admit.count()

df_admit = df_raw[(df_raw.admit==1)]
#df_admit.sort().head()

df_raw.groupby('admit')['gre', 'gpa'].count()
# Out:
#        gre  gpa
# admit
# 0      271  272
# 1      127  126

# %% [markdown]
# #### Question 3. Why would GRE have a larger STD than GPA?

# %% [markdown]
# Answer: for GPA the datapoints are closer to mean and in the case of GRE the data points are father to mean resulting in a higher standard deviation.

# %% [markdown]
# #### Question 4. Drop data points with missing data

# %%
df_values = df_raw.dropna(axis = 0, how = 'any')
df_values
# Out:
#      admit    gre   gpa  prestige
# 0        0  380.0  3.61       3.0
# 1        1  660.0  3.67       3.0
# 2        1  800.0  4.00       1.0
# 3        1  640.0  3.19       4.0
# 4        0  520.0  2.93       4.0
# 5        1  760.0  3.00       2.0
# 6        1  560.0  2.98       1.0
# 7        0  400.0  3.08       2.0
# 8        1  540.0  3.39       3.0
# 9        0  700.0  3.92       2.0
# 10       0  800.0  4.00       4.0
# 11       0  440.0  3.22       1.0
# 12       1  760.0  4.00       1.0
# 13       0  700.0  3.08       2.0
# 14       1  700.0  4.00       1.0
# 15       0  480.0  3.44       3.0
# 16       0  780.0  3.87       4.0
# 17       0  360.0  2.56       3.0
# 18       0  800.0  3.75       2.0
# 19       1  540.0  3.81       1.0
# 20       0  500.0  3.17       3.0
# 21       1  660.0  3.63       2.0
# 22       0  600.0  2.82       4.0
# 23       0  680.0  3.19       4.0
# 24       1  760.0  3.35       2.0
# 25       1  800.0  3.66       1.0
# ...

# %% [markdown]
# #### Question 5. Confirm that you dropped the correct data. How can you tell?

# %%
#See if there is any minus function.
df_nulls = df_raw.isnull().any(axis = 0)
df_nulls
# Out:
# admit       False
# gre          True
# gpa          True
# prestige     True
# dtype: bool

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 6. Create box plots for GRE and GPA

# %%
#boxplot
df_raw[['gre', 'gpa']].plot.box(grid = True, color = 'Grey')

# %%
#boxplot 2 
df_raw['gpa'].plot.box(grid = True, color = 'Red')

# %% [markdown]
# #### Question 7. What do this plots show?

# %% [markdown]
# Answer: THe Box plot Shows the following:
# 1. Outlyers
# 2. Quartiles(25, 50, 75)
# 3. Min Value
# 4. Max Value
# 5. Mean.

# %% [markdown]
# #### Question 8. Describe each distribution

# %%
# plot the distribution of each variable 
my_colors = 'rgbkymc'
df_raw[['admit', 'gre', 'gpa']].plot.hist(grid = True, color = my_colors);

# %%
#-----------------------------
# plot the distribution of each variable 
#my_colors = 'rgbkymc'
#g= df_raw['admit'].plot.bar(grid = True)
#g = df_raw.plot(kind = 'scatter', x='gre', y = 'admit')

#g = df_raw.plot.scatter(x='gre', y = 'admit', color = 'Green')

#g.color = 'Green'
#g = df_raw.plot.hist #(grid = True, color = 'Green')


#g.set_title('GRE to Admit Ratio')
#g.set_xlabel('GRE Score', fontsize = 10)
#g.set_ylabel('Admitted?', fontsize = 10)

#df_raw[['admit', 'gre', 'gpa']].plot.hist(grid = True, color = my_colors);
#g = df['example1'].plot.barh(grid=True,figsize=(30,30), color = 'Green', xlim = (0, 35), ylim = (0, 10))

df_raw.plot.hist('gre')
df_raw.plot.hist('gpa')

# %%
import matplotlib.pyplot as plt
import numpy as np
from mpl_toolkits.mplot3d import axes3d


fig = plt.figure()
ax = fig.add_subplot(111, projection = '3d')

x = df_raw['gre']
y = df_raw['gpa']
Z = df_raw['admit']

#ax.scatter('x', 'y', 'z', c='r', marker ='o')
x,y,z = axes3d.get_test_data(0.05)
ax.plot_wireframe(x,y,z, rstride = 10, cstride = 10)
ax.set_xlabel('x-axis')
ax.set_ylabel('y-axis')
ax.set_zlabel('z-axis')

plt.show()

# %%
x,y,z = axes3d.get_test_data

# %%
get_test_data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-106-a4d57930ac18> in <module>()
# ----> 1 get_test_data
#
# NameError: name 'get_test_data' is not defined

# %% [markdown]
# #### Question 9.  If our model had an assumption of a normal distribution would we meet that requirement?

# %%
Yes

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 10.  Does this distribution need correction? If so, why? How?

# %%
yes, the data has to be corrected by removing the null values.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 11. Which of our variables are potentially colinear?

# %%
# create a correlation matrix for the data
df_raw.corr()
# Out:
#              admit       gre       gpa  prestige
# admit     1.000000  0.182919  0.175952 -0.241355
# gre       0.182919  1.000000  0.382408 -0.124533
# gpa       0.175952  0.382408  1.000000 -0.059031
# prestige -0.241355 -0.124533 -0.059031  1.000000

# %% [markdown]
# #### Question 12. What did you find?

# %% [markdown]
# Answer: Admit is having positive colinearity with 'GRE, GPA' and negative colinearity with 'Prestige'

# %% [markdown]
# #### Question 13. Write an analysis plan for exploring the association between grad school admissions rates and prestige of  undergraduate schools.

# %% [markdown]
# Answer:

# %% [markdown]
# #### Question 14. What is your hypothesis?

# %% [markdown]
# Answer: Admit is having positive colinearity with 'GRE, GPA' and negative colinearity with 'Prestige'

# %% [markdown]
# ## Bonus/Advanced

# %% [markdown]
# #### 1. Bonus: Explore alternatives to dropping obervations with missing data

# %% [markdown]
# #### 2. Bonus: Log transform the skewed data

# %% [markdown]
# #### 3. Advanced: Impute missing data
